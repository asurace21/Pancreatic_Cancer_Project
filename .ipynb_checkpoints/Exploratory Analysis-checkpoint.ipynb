# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = "Resources/Debernardi et al 2020 data.csv"
markers_df = pd.read_csv(data)
markers_df.head()
# Out:
#   sample_id patient_cohort sample_origin  age sex  diagnosis stage  \
# 0        S1        Cohort1          BPTB   33   F          1   NaN
# 1       S10        Cohort1          BPTB   81   F          1   NaN
# 2      S100        Cohort2          BPTB   51   M          1   NaN
# 3      S101        Cohort2          BPTB   61   M          1   NaN
# 4      S102        Cohort2          BPTB   62   M          1   NaN
#
#   benign_sample_diagnosis  plasma_CA19_9  creatinine     LYVE1      REG1B  \
# 0                     NaN           11.7     1.83222  0.893219   52.94884
# 1                     NaN            NaN     0.97266  2.037585   94.46703
# 2                     NaN            7.0     0.78039  0.145589  102.36600
# 3                     NaN            8.0     0.70122  0.002805   60.57900
# 4                     NaN            9.0     0.21489  0.000860   65.54000
#
#          TFF1     REG1A
# 0  654.282174  1262.000
# 1  209.488250   228.407
# 2  461.141000       NaN
# 3  142.950000       NaN
# 4   41.088000       NaN

# %%
markers_df.dtypes
# Out:
# sample_id                   object
# patient_cohort              object
# sample_origin               object
# age                          int64
# sex                         object
# diagnosis                    int64
# stage                       object
# benign_sample_diagnosis     object
# plasma_CA19_9              float64
# creatinine                 float64
# LYVE1                      float64
# REG1B                      float64
# TFF1                       float64
# REG1A                      float64
# dtype: object

# %%
df_columns = markers_df.columns.tolist()

# %%
for item in df_columns:
    print(f"There are {markers_df[item].isna().sum()} blank rows in column {item}.")
# Out:
# There are 0 blank rows in column sample_id.
# There are 0 blank rows in column patient_cohort.
# There are 0 blank rows in column sample_origin.
# There are 0 blank rows in column age.
# There are 0 blank rows in column sex.
# There are 0 blank rows in column diagnosis.
# There are 391 blank rows in column stage.
# There are 382 blank rows in column benign_sample_diagnosis.
# There are 240 blank rows in column plasma_CA19_9.
# There are 0 blank rows in column creatinine.
# There are 0 blank rows in column LYVE1.
# There are 0 blank rows in column REG1B.
# There are 0 blank rows in column TFF1.
# There are 284 blank rows in column REG1A.

# %%
benign_avg = "Resources/benign_avg.csv"
benign_avg_df = pd.read_csv(benign_avg)
benign_avg_df
# Out:
#                               benign_sample_diagnosis  plasma_avg  creat_avg  \
# 0                                     Abdominal Pain        24.67       0.66
# 1             Biliary Stricture (Secondary to Stent)        31.62       0.38
# 2                                       Cholecystitis         NaN       0.34
# 3                                      Cholecystitis        10.00       0.72
# 4                            Cholecystitis (Chronic)        17.00       0.70
# 5              Cholecystitis (Chronic) Cholelithiasis        5.00       0.63
# 6              Cholecystitis (Chronic) Cholesterolsis       29.00       0.93
# 7                                   Choledochal Cyst        15.00       0.17
# 8                                Choledocholiathiasis       14.83       0.72
# 9                               Choledocholiathiasis          NaN       1.52
# 10    Cholelithiasis with adenomyomatous hyperplasia          NaN       1.39
# 11                                 Duodenal Stricture       68.72       0.41
# 12                                         Duodenitis         NaN       0.38
# 13                                Gallbladder polyps        15.00       0.82
# 14                              Gallbladder Porcelain         NaN       0.41
# 15                                         Gallstones        7.00       0.90
# 16                                        Gallstones        17.00       1.11
# 17                           Gallstones - Incidental        42.00       0.22
# 18                                         Gastritis        25.00       1.36
# 19                              Gastritis and Reflux          NaN       1.02
# 20             Ill defined lesion in uncinate process       37.00       1.41
# 21               Ischaemic Common Bile Duct Stricture       19.00       0.78
# 22                                       Pancreatitis      151.59       1.10
# 23                                      Pancreatitis        11.04       0.64
# 24                             Pancreatitis (Abscess)         NaN       0.78
# 25                               Pancreatitis (Acute)       25.00       1.13
# 26          Pancreatitis (Alcohol-Chronic-Pseuodcyst)      115.40       0.80
# 27                     Pancreatitis (Alcohol-Chronic)       34.24       0.64
# 28                             Pancreatitis (Alcohol)       19.00       0.57
# 29                         Pancreatitis (Autoimmune)        18.10       0.67
# 30                 Pancreatitis (Chronic-Pseudocyst)        10.00       0.16
# 31                            Pancreatitis (Chronic)         8.65       1.08
# 32         Pancreatitis (Chronic) (Later became PDAC)      190.70       1.42
# 33         Pancreatitis (Chronic) Choledocholithiasis         NaN       0.85
# 34        Pancreatitis (Gallstone-Alcohol-Pseudocyst)        9.00       0.35
# 35                Pancreatitis (Gallstone-Pseudocyst)        4.00       0.67
# 36                          Pancreatitis (Gallstone)        21.00       0.66
# 37                 Pancreatitis (Hereditary-Chronic)         7.90       1.01
# 38                Pancreatitis (Hypertriglyceridemia)       32.30       0.46
# 39                          Pancreatitis (Idiopathic)        1.00       0.83
# 40                         Pancreatitis (Idiopathic)        12.07       1.37
# 41                          Pancreatitis (Pseudocyst)       13.00       0.45
# 42        Pancreato-jejunostomy Anastomoses Stricture        6.71       0.39
# 43                   Premalignant lesions-Adenoma-NOS       10.00       0.21
# 44  Premalignant lesions-Mucinous cystadenocarcino...       11.00       0.80
# 45      Premalignant lesions-Mucinous cystadenoma-NOS       11.50       0.50
# 46           Premalignant lesions-Tubular adenoma-NOS       52.00       0.37
# 47     Premalignant lesions-Tubulovillous adenoma-NOS         NaN       0.09
# 48           Premalignant lesions-Villous adenoma-NOS       16.00       0.50
# 49                           Serous cystadenoma - NOS       22.50       0.63
# 50                         Serous microcystic adenoma       17.00       0.24
# 51                           Simple benign liver cyst         NaN       0.59
#
#     lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 0        2.37      25.52    175.44        NaN
# 1        3.71     215.58    656.79    1305.15
# 2        0.14      20.01     41.58        NaN
# 3        0.74      21.41     68.95        NaN
# 4        0.97      76.26    617.70        NaN
# 5        2.26      45.52    391.26        NaN
# 6        1.56      32.09    191.50        NaN
# 7        0.21      18.35      0.01        NaN
# 8        2.59     160.94    709.87     248.83
# 9        1.23      42.51    674.29        NaN
# 10       1.21      58.97    663.82        NaN
# 11       2.40     137.11     55.73     933.05
# 12       0.25       1.40      0.03        NaN
# 13       0.22      26.53    373.18        NaN
# 14       0.00       1.39      6.19        NaN
# 15       1.44      27.64    189.08      24.29
# 16       0.76      54.84    140.11        NaN
# 17       0.56      31.03     82.57        NaN
# 18       4.12      99.15    425.39        NaN
# 19       1.50      11.12     84.65        NaN
# 20       1.04      90.68    565.79        NaN
# 21       6.02      19.02    566.49        NaN
# 22       2.96      60.25    730.19     299.77
# 23       1.02      29.10    380.86     478.13
# 24       1.08       5.80    181.46        NaN
# 25       3.57     240.24    671.28        NaN
# 26       2.56      34.61    547.52      76.61
# 27       1.40      36.20    274.50      73.81
# 28       5.20      51.80    673.79    1939.00
# 29       3.00     347.19   1256.78    2209.50
# 30       0.45     151.44    216.91        NaN
# 31       2.72     102.13    663.96     612.07
# 32       7.62     207.53   1268.77    1150.65
# 33       4.21      53.65    454.83        NaN
# 34       0.10       6.13    107.99        NaN
# 35       0.94      19.43    137.17        NaN
# 36       0.73       6.49    172.23        NaN
# 37       1.57     128.28    339.01    4211.00
# 38       4.03      34.05    308.70     774.00
# 39       0.00       5.52     83.18        NaN
# 40       3.65     136.99    766.87    3289.00
# 41       3.28      11.24    169.30        NaN
# 42       0.00       1.42     38.31      26.41
# 43       0.44      26.96     40.24        NaN
# 44       0.00       3.75    336.58        NaN
# 45       0.46      17.77    121.96        NaN
# 46       0.59      19.72    207.65        NaN
# 47       0.00       4.91      5.62        NaN
# 48       0.69      14.99    139.52        NaN
# 49       2.08      81.23    346.07        NaN
# 50       0.32      14.01     41.18        NaN
# 51       0.93      29.33      1.88        NaN

# %%
control_avg = "Resources/control_avg.csv"
control_avg_df = pd.read_csv(control_avg)
control_avg_df
# Out:
#    control_group  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  \
# 0            NaN        8.75        0.8       1.21      41.33    169.02
#
#    reg1a_avg
# 0     227.87

# %%
control_y = control_avg_df.drop("control_group", axis=1)
X = control_y.columns.tolist()

values = []
for item in control_y.columns.tolist():
    x = control_y[item].tolist()[0]
    values.append(x)
    
plt.bar(X, values)
plt.title("Control Group Marker Values")
# Out:
# Text(0.5, 1.0, 'Control Group Marker Values')

# %%
stage_avg = "Resources/stage_avg.csv"
stage_avg_df = pd.read_csv(stage_avg)
stage_avg_df
# Out:
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 0     I         NaN       0.57      12.02     431.42    874.10        NaN
# 1    IA       10.67       0.88       2.03      87.43    330.60     182.73
# 2    IB     1486.87       0.62       3.07     128.82    564.48    1811.72
# 3    II         NaN       1.02       9.98     503.06   1467.86    1929.56
# 4   IIA      592.91       0.64       3.11     206.68   1607.51     636.39
# 5   IIB     1345.56       0.78       5.29     199.20   1068.57     764.18
# 6   III     1662.51       1.07       6.30     221.19   1118.93    1148.34
# 7    IV     3430.30       1.08       7.35     316.46   1632.15    4132.15

# %%
b = stage_avg_df["stage"].tolist()
b

for item in b:
    x = stage_avg_df.loc[stage_avg_df["stage"] == item]
    print(x)
    print(x["creat_avg"])
# Out:
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 0     I         NaN       0.57      12.02     431.42     874.1        NaN
# 0    0.57
# Name: creat_avg, dtype: float64
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 1    IA       10.67       0.88       2.03      87.43     330.6     182.73
# 1    0.88
# Name: creat_avg, dtype: float64
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 2    IB     1486.87       0.62       3.07     128.82    564.48    1811.72
# 2    0.62
# Name: creat_avg, dtype: float64
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 3    II         NaN       1.02       9.98     503.06   1467.86    1929.56
# 3    1.02
# Name: creat_avg, dtype: float64
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 4   IIA      592.91       0.64       3.11     206.68   1607.51     636.39
# 4    0.64
# Name: creat_avg, dtype: float64
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 5   IIB     1345.56       0.78       5.29      199.2   1068.57     764.18
# 5    0.78
# Name: creat_avg, dtype: float64
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 6   III     1662.51       1.07        6.3     221.19   1118.93    1148.34
# 6    1.07
# Name: creat_avg, dtype: float64
#   stage  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  reg1a_avg
# 7    IV      3430.3       1.08       7.35     316.46   1632.15    4132.15
# 7    1.08
# Name: creat_avg, dtype: float64

# %%
gender_stats = "Resources/gender_statistics.csv"
gender_stats_df = pd.read_csv(gender_stats)
gender_stats_df
# Out:
#   sex  sex_count  plasma_avg  creat_avg  lyve1_avg  reg1b_avg  tff1_avg  \
# 0   M        291      836.27       0.97       3.68     143.10    715.17
# 1   F        299      479.88       0.74       2.46      81.29    483.70
#
#    reg1a_avg
# 0     881.46
# 1     532.00

# %%
diagnosis_gender_stats = "Resources/diagnosis_gender_statistics.csv"
diagnosis_gender_stats_df = pd.read_csv(diagnosis_gender_stats)
diagnosis_gender_stats_df
# Out:
#    diagnosis sex  diagnosis_count  plasma_avg  creat_avg  lyve1_avg  \
# 0          1   F              115       10.21       0.68       1.01
# 1          1   M               68        6.26       0.99       1.55
# 2          2   F              101       17.28       0.73       1.56
# 3          2   M              107      111.52       0.96       2.58
# 4          3   F               83     1317.52       0.84       5.57
# 5          3   M              116     1594.21       0.97       5.95
#
#    reg1b_avg  tff1_avg  reg1a_avg
# 0      31.02    148.20     182.04
# 1      58.75    204.24     274.88
# 2      48.84    298.61     550.30
# 3      78.65    589.51     545.89
# 4     190.41   1173.78     767.64
# 5     251.99   1130.60    1392.89
